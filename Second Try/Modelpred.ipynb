# %%
import pandas as pd

pd.options.display.max_seq_items = 20000
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 2000)

# %%
from pymongo import MongoClient

 

# Create a client instance of MongoClient

client = MongoClient('mongodb+srv://friedrich_hermann:uTkxuhFf2bNU-vIIEY@outbound-production.h7ybo.mongodb.net/outbound')

 

# Get the database object

# Here name of the database is "sample"
db = client.outbound

 

# Get the collection object

# Here name of the database is "states"

collection  = db.raw

 
lister=[]
# Make a query to list all the documents

for doc in collection.find():

    #Print each document
    lister.append(doc)

# %%
a.columns
# Out:
# Index(['_id', 'name', 'domain', 'hasValidDomain', 'lastUpdated', 'sources.Startupdetector - GROW._id', 'sources.Startupdetector - GROW.name', 'sources.Startupdetector - GROW.domain', 'sources.Startupdetector - GROW.urls', 'sources.Startupdetector - GROW.description', 'sources.Startupdetector - GROW.sources', 'sources.Startupdetector - GROW.founders', 'sources.Startupdetector - GROW.yearFounded', 'sources.Startupdetector - GROW.notes', 'sources.Startupdetector - GROW.industries', 'sources.Startupdetector - GROW.location', 'sources.Startupdetector - GROW.fundingAmount', 'sources.Startupdetector - GROW.clientFocus', 'sources.Startupdetector - GROW.hasValidDomain', 'sources.Startupdetector - GROW.uploadedToAffinity', 'sources.Startupdetector - GROW.lastUpdated', 'sources.Startupdetector - START._id', 'sources.Startupdetector - START.name', 'sources.Startupdetector - START.domain', 'sources.Startupdetector - START.urls', 'sources.Startupdetector - START.description', 'sources.Startupdetec
# ...

# %% [markdown]
# Look at all the columns available in MongoDB

# %% [markdown]
# - '_id'
# - 'name'
# - 'domain'
# - 'originSource'
# - 'sources',
# - 'registrationNumber'
# - 'registrationCountry'
# - 'launchYear',
# - 'launchMonth'
# - 'industries'
# - 'tagline'
# - 'about'
# - 'locationCity'
# - 'locationCountry'
# - 'companyLinkedinUrl'
# - 'crunchbaseUrl'
# - 'latestEmployeeCount'
# - 'founders'
# - 'growthStage'
# - 'clientFocus'
# - 'eurusdRate'
# - 'totalFundingEUR'
# - 'totalFundingUSD'
# - 'lastFundingEUR'
# - 'lastFundingUSD'
# - 'lastFundingDate'
# - 'valuationEUR'
# - 'valuationUSD'
# - 'investors'
# - 'notes'
# - 'hasValidDomain'
# - 'lastUpdated'
# - 'uploadedToAffinity'
# - 'affinityListIDs'
# - 'affinityListOwnerID'
# - 'affinityOrgID'
# - 'uploadedToAffinityTime'
# - 'locationContinent'
# - 'readyForAffinity'
# - 'unwantedIndustry'
# - 'filteredOut'
# - 'filteredOutReasons'
# - 'linkedinScrapingChecked'

# %%
col_needed=["_id","name","domain","registrationCountry","launchYear","industries","about","locationCity","locationCountry","companyLinkedinUrl","founders","growthStage","totalFundingEUR","lastFundingDate","investors","hasValidDomain"]
col_total_needed=['_id', 'name', 'hasValidDomain', 'sources.Startupdetector - GROW.founders', 'sources.Startupdetector - GROW.yearFounded', 'sources.Startupdetector - GROW.industries', 'sources.Startupdetector - GROW.location', 'sources.Startupdetector - GROW.fundingAmount', 'sources.Startupdetector - START.founders', 'sources.Startupdetector - START.yearFounded', 'sources.Startupdetector - START.industries', 'sources.Startupdetector - START.location', 'sources.Startupdetector - START.fundingAmount', 'sources.dealroom.type', 'sources.dealroom.about', 'sources.dealroom.website_url', 'sources.dealroom.linkedin_url','sources.dealroom.industries','sources.dealroom.growth_stage', 'sources.dealroom.hq_locations', 'sources.dealroom.ownerships', 'sources.dealroom.launch_year', 'sources.dealroom.launch_month', 'sources.dealroom.total_funding','sources.dealroom.company_status', 'sources.dealroom.team.items', 'sources.dealroom.team.total', 'sources.dealroom.investors.items', 'sources.dealroom.investors.total', 'sources.dealroom.fundings.items', 'sources.dealroom.fundings.total', 'sources.dealroom.patents_count', 'sources.deutsche startups.founders', 'sources.deutsche startups.companyLinkedinUrl', 'sources.deutsche startups.location', 'sources.deutsche startups.industries', 'sources.dealroom.last_funding_date', 'sources.Startupdetector - START.registrationCountry', 'sources.Startupdetector - START.companyLinkedinUrl', 'sources.Startupdetector - GROW.registrationCountry', 'sources.Startupdetector - GROW.investors', 'sources.Startupdetector - GROW.companyLinkedinUrl',  'sources.metabeta.companyLinkedinUrl', 'sources.metabeta.hasValidDomain', 'sources.metabeta.domain', 'sources.metabeta.founders', 'sources.metabeta.yearFounded',  'sources.metabeta.totalFundingAmountEUR', 'sources.metabeta.industries']

# %%
a=[]
from bson.objectid import ObjectId
for i in collection.find():
    a.append(pd.json_normalize(i))

df=pd.concat(a)

# %%
df=df[col_total_needed]

# %% [markdown]
# Rename Columns of Dataframe

# %%
df.rename(columns={'_id':'id','hasValidDomain':'hasValidDomain.1', 'sources.Startupdetector - GROW.founders':'founders.1', 'sources.Startupdetector - GROW.yearFounded':'year_founded.1', 'sources.Startupdetector - GROW.industries':'industries.1', 'sources.Startupdetector - GROW.location':'country.1', 'sources.Startupdetector - GROW.fundingAmount':'total_funding.1', 'sources.Startupdetector - START.founders':'founders.2', 'sources.Startupdetector - START.yearFounded':'year_founded.2', 'sources.Startupdetector - START.industries':'industries.2', 'sources.Startupdetector - START.location':'country.2', 'sources.Startupdetector - START.fundingAmount':'total_funding.2', 'sources.dealroom.type':'type.1', 'sources.dealroom.about':'about.1', 'sources.dealroom.website_url':'website_url.1', 'sources.dealroom.linkedin_url':'linkedin_url.1',  'sources.dealroom.industries':'industries.3' ,'sources.dealroom.growth_stage':'growth_stage.1', 'sources.dealroom.hq_locations':'country.3', 'sources.dealroom.ownerships':'ownerships.1', 'sources.dealroom.launch_year':'year_founded.3', 'sources.dealroom.launch_month':'month_founded.1', 'sources.dealroom.total_funding':'total_funding.3', 'sources.dealroom.company_status':'company_status.1', 'sources.dealroom.team.items':'founders.3', 'sources.dealroom.team.total':'founders_total.1', 'sources.dealroom.investors.items':'investors.1', 'sources.dealroom.investors.total':'investors_total.1', 'sources.dealroom.fundings.items':'fundings_items.1', 'sources.dealroom.fundings.total':'fundings_total.1', 'sources.dealroom.patents_count':'patents_count.1', 'sources.deutsche startups.founders':'founders.4', 'startups.companyLinkedinUrl':'linkedin_url.1', 'sources.deutsche startups.location':'country.4', 'sources.deutsche startups.industries':'industries.4', 'sources.dealroom.last_funding_date':'last_funding_date.1', 'sources.Startupdetector - START.registrationCountry':'country.5', 'sources.Startupdetector - START.companyLinkedinUrl':'linkedin_url.2', 'sources.Startupdetector - GROW.registrationCountry':'country.6', 'sources.Startupdetector - GROW.investors':'investors.2', 'sources.Startupdetector - GROW.companyLinkedinUrl':'linkedin_url.3',  'sources.metabeta.companyLinkedinUrl':'linkedin_url.4', 'sources.metabeta.hasValidDomain':'hasValidDomain.2', 'sources.metabeta.domain':'website_url.2', 'sources.metabeta.founders':'founders.5', 'sources.metabeta.yearFounded':'year_founded.4',  'sources.metabeta.totalFundingAmountEUR':'total_funding.4', 'sources.metabeta.industries':'industries.5','sources.deutsche startups.companyLinkedinUrl':'linkedin_url.5'}, inplace=True)

# %%
df.head()
# Out:
#                          id                      name  hasValidDomain.1                                         founders.1 year_founded.1    industries.1 country.1 total_funding.1                                         founders.2 year_founded.2              industries.2  country.2 total_funding.2   type.1 about.1              website_url.1                              linkedin_url.1                                industries.3 growth_stage.1                                          country.3                    ownerships.1  year_founded.3  month_founded.1  total_funding.3 company_status.1 founders.3  founders_total.1                                        investors.1  investors_total.1                                   fundings_items.1  fundings_total.1  patents_count.1 founders.4 linkedin_url.5 country.4 industries.4 last_funding_date.1 country.5 linkedin_url.2 country.6 investors.2 linkedin_url.3 linkedin_url.4 hasValidDomain.2 website_url.2 founders.5 year_founded.4 total_funding.
# ...

# %%
from dotenv.main import load_dotenv
import os
load_dotenv()
API_KEY=os.environ["api_key"]

# %%
# from CompanyList-Search.ipynb:
import pandas as pd
import requests
import json
from pandas import json_normalize
from requests.auth import HTTPBasicAuth

def list_finder(companylist:list, api, fields="id,name,type,deleted,path,tagline,about,url,website_url,employees,employees_latest,corporate_industries,service_industries,technologies,growth_stage,traffic_summary,delivery_method,launch_year,launch_month,has_promising_founder,has_strong_founder,has_super_founder,total_funding,total_funding_source,last_funding,last_funding_source,company_status,last_updated,last_updated_utc,created_utc,similarweb_3_months_growth_unique,similarweb_6_months_growth_unique,similarweb_12_months_growth_unique,app_3_months_growth_unique,app_6_months_growth_unique,app_12_months_growth_unique,employee_3_months_growth_unique,employee_6_months_growth_unique,employee_6_months_growth_unique,employee_12_months_growth_unique,kpi_summary,team,investors,fundings,traffic,job_openings"):
    """
    will import the company information according to name, or website in the provided list. 
    Fields are set to "id,name,type,deleted,path,tagline,about,url,website_url,employees,employees_latest,corporate_industries,service_industries,technologies,growth_stage,traffic_summary,delivery_method,launch_year,launch_month,has_promising_founder,has_strong_founder,has_super_founder,total_funding,total_funding_source,last_funding,last_funding_source,company_status,last_updated,last_updated_utc,created_utc,similarweb_3_months_growth_unique,similarweb_6_months_growth_unique,similarweb_12_months_growth_unique,app_3_months_growth_unique,app_6_months_growth_unique,app_12_months_growth_unique,employee_3_months_growth_unique,employee_6_months_growth_unique,employee_6_months_growth_unique,employee_12_months_growth_unique,kpi_summary,team,investors,fundings,traffic,job_openings,exits,trading_multiple"
    by default. api key has to be provided in the api field. 
    
    Function will return the data in json as well as a list of names no information has been found for.
    """
    api_url="https://api.dealroom.co/api/v1/companies"
    API_KEY=api
    auth=HTTPBasicAuth(API_KEY, '')
    
    headers = {'Content-Type': 'application/json'}
    data_list=[]
    failed_names=[]
    
    for i in companylist:
        data={"keyword": "{}".format(i),
              "keyword_type": "website_domain",
              "keyword_match_type": "exact",
              "fields":fields,
              "limit": 1,
              "offset": 0
             }
        response = requests.post(api_url,data=json.dumps(data),auth=auth,headers=headers)
        data=response.json()
        if len(data["items"])==0:
            failed_names.append("{}".format(i))
        else:
            data_list.append(data["items"][0])
        
    return data_list, failed_names

# %%
for i in db.list_collection_names():
    print(i)
# Out:
# companies
# domainsOnOutboundList
# summary
# combinedScrapersCache
# standardizedSourcesData
# raw

# %%
df_mode.corr()
# Out:
# /var/folders/k0/ldv3tm456fl7jrgd0xn0vy5h0000gn/T/ipykernel_12057/2612738855.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mode.corr()
#                        about  website_url  facebook_url  twitter_url  \
# about               1.000000          NaN      0.059379     0.061044
# website_url              NaN          NaN           NaN          NaN
# facebook_url        0.059379          NaN      1.000000     0.326860
# twitter_url         0.061044          NaN      0.326860     1.000000
# linkedin_url       -0.051197          NaN     -0.026931     0.026939
# total_funding       0.008026          NaN      0.022983     0.016382
# patents_count      -0.000234          NaN      0.006498     0.008432
# launch_year         0.065090          NaN      0.033821     0.037053
# ...

# %% [markdown]
# # 1. Prepare Routines to impute missing data in prediction

# %% [markdown]
# fields that need imputation:
# 1. tot. funding
# 2. patents count
# 3. fundings total
# 4. team male + female
# 5. avg time funding
# 6. Country + City

# %% [markdown]
# Find out which imputation fields need which columns

# %%
df_mode=pd.read_pickle("/Users/klaus/Documents/Jarvis/Second Try/Data/df_mode_30.11")

# %%
df_mode.columns
# Out:
# Index(['name', 'about', 'website_url', 'facebook_url', 'twitter_url',
#        'linkedin_url', 'total_funding', 'patents_count', 'launch_year',
#        'investors_total', 'fundings_total', 'country_name', 'city_name',
#        'industry_name', 'number_top_schools', 'number_schools', 'team_male',
#        'team_female', 'avg_time_funding', 'Y', 'is_bootstrapped',
#        'number_top_inv', 'missing_values'],
#       dtype='object')

# %% [markdown]
# 1. tot_funding

# %%
df_mode.corr()["total_funding"]
# Out:
# /var/folders/k0/ldv3tm456fl7jrgd0xn0vy5h0000gn/T/ipykernel_75623/3930227095.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mode.corr()["total_funding"]
# about                 0.008026
# website_url                NaN
# facebook_url          0.022983
# twitter_url           0.016382
# linkedin_url          0.000841
# total_funding         1.000000
# patents_count         0.007668
# launch_year           0.059982
# investors_total       0.027531
# fundings_total        0.057398
# country_name          0.000600
# city_name             0.002031
# industry_name        -0.001776
# number_top_schools    0.008902
# number_schools        0.010922
# team_male             0.003578
# team_female          -0.006402
# avg_time_funding      0.061508
# Y                     0.015900
# is_bootstrapped      -0.046821
# ...

# %% [markdown]
# Fundings total, investors_total, launch year, avg_time_funding, is_bootstrapped, missing_values
